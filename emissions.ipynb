# %%
import numpy as np
import pandas as pd
import sklearn as sk

# %% [markdown]
# # Reading in Data

# %% [markdown]
# ### AQI

# %%
df_daily_aqi = pd.read_csv('daily_aqi_by_county_2021.csv')

# %%
df_daily_aqi.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI Category  \
# 0    Alabama      DeKalb           1           49  2021-01-01   30     Good
# 1    Alabama      DeKalb           1           49  2021-01-02   27     Good
# 2    Alabama      DeKalb           1           49  2021-01-03   34     Good
# 3    Alabama      DeKalb           1           49  2021-01-04   36     Good
# 4    Alabama      DeKalb           1           49  2021-01-05   31     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              Ozone   01-049-9991                          1
# 1              Ozone   01-049-9991                          1
# 2              Ozone   01-049-9991                          1
# 3              Ozone   01-049-9991                          1
# 4              Ozone   01-049-9991                          1

# %% [markdown]
# ### HAPS, VOCS, LEAD

# %%
df_daily_HAPS = pd.read_csv('daily_HAPS_2021.csv')
df_daily_VOCS = pd.read_csv('daily_VOCS_2021.csv')
df_daily_LEAD = pd.read_csv('daily_LEAD_2021.csv')

# %%
df_daily_HAPS.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0          19           45        19           43502   16  41.823283
# 1          19           45        19           43502   16  41.823283
# 2          19           45        19           43502   16  41.823283
# 3          19           45        19           43502   16  41.823283
# 4          19           45        19           43502   16  41.823283
#
#    Longitude  Datum Parameter Name Sample Duration  ...  AQI Method Code  \
# 0 -90.211982  WGS84   Formaldehyde         24 HOUR  ...  NaN         202
# 1 -90.211982  WGS84   Formaldehyde         24 HOUR  ...  NaN         202
# 2 -90.211982  WGS84   Formaldehyde         24 HOUR  ...  NaN         202
# 3 -90.211982  WGS84   Formaldehyde         24 HOUR  ...  NaN         202
# 4 -90.211982  WGS84   Formaldehyde         24 HOUR  ...  NaN         202
#
#                                          Method Name       Local Site Name  \
# ...
